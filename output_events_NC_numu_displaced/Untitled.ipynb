# %%
import pandas as pd

# Load the data
data = pd.read_csv("observables_new_897.16.csv.zip")


# Filter rows where both has_charm == 1 and has_pion == 1
charm_pion_events = data['weight'].unique() 

# Print the filtered rows
print(charm_pion_events)
# Out:
# [0.00116797 0.0017906  0.00126143 ... 0.00163805 0.00246875 0.00275612]
