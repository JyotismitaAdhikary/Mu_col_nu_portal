# %% [markdown]
# # Project: Neutrino Portal at the Muon Collider

# %% [markdown]
# ## Load Libraries

# %%
import os
import pandas as pd
import numpy as np
import pathlib
import ast
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import json

# %% [markdown]
# ## Calculate Observables

# %% [markdown]
# -  this function reads the particles in a csv file and exports a data frame

# %%
data = pd.read_csv("output_events_NC_numu/events_22.53.csv.zip")

# %%
data
# Out:
#        ievent  iparticle  truth_energy  pid     px     py     pz      e  \
# 0         NaN          0         22.53   14 -0.934 -0.835  7.702  7.803
# 1         NaN          1         22.53  211 -0.282 -0.034  1.208  1.249
# 2         NaN          2         22.53 -211  1.316 -0.109  2.203  2.572
# 3         NaN          3         22.53  -13 -0.311  0.066  0.355  0.488
# 4         NaN          4         22.53   14  0.223  0.523  4.047  4.087
# ...       ...        ...           ...  ...    ...    ...    ...    ...
# 27676     NaN          4         22.53  -14 -0.884 -0.032  2.474  2.627
# 27677     NaN          5         22.53  321  0.044 -0.085  0.677  0.843
# 27678     NaN          6         22.53  -13  0.262  0.260  3.125  3.149
# 27679     NaN          7         22.53   14 -0.253 -0.503  3.075  3.126
# 27680     NaN          8         22.53  130 -0.450  0.402  1.971  2.120
#
#        parent_pid1  parent_pid2
# 0               14           14
# 1                4         2203
# 2             -411           90
# 3             4122           90
# 4             4122           90
# ...            ...          ...
# 27676         -421           90
# 27677         -421           90
# 27678          411           90
# 27679          411           90
# 27680          311          311
#
# [27681 rows x 10 columns]

# %% [markdown]
# - function that fixes missing ievent entries

# %%
def fix_dataframe(data):

    # Initialize the column 'ievent' with zeros
    data['ievent'] = 0
    # Variable to keep track of the increment for column 'ievent'
    counter = 0
    # Loop through the DataFrame rows
    for index, row in data.iterrows():
        if row['iparticle'] == 0: counter += 1
        data.at[index, 'ievent'] = counter
    #return
    return data

# %%
data = fix_dataframe(data)
data
# Out:
#        ievent  iparticle  truth_energy  pid     px     py     pz      e  \
# 0           1          0         22.53   14 -0.934 -0.835  7.702  7.803
# 1           1          1         22.53  211 -0.282 -0.034  1.208  1.249
# 2           1          2         22.53 -211  1.316 -0.109  2.203  2.572
# 3           1          3         22.53  -13 -0.311  0.066  0.355  0.488
# 4           1          4         22.53   14  0.223  0.523  4.047  4.087
# ...       ...        ...           ...  ...    ...    ...    ...    ...
# 27676    2368          4         22.53  -14 -0.884 -0.032  2.474  2.627
# 27677    2368          5         22.53  321  0.044 -0.085  0.677  0.843
# 27678    2368          6         22.53  -13  0.262  0.260  3.125  3.149
# 27679    2368          7         22.53   14 -0.253 -0.503  3.075  3.126
# 27680    2368          8         22.53  130 -0.450  0.402  1.971  2.120
#
#        parent_pid1  parent_pid2
# 0               14           14
# 1                4         2203
# 2             -411           90
# 3             4122           90
# 4             4122           90
# ...            ...          ...
# 27676         -421           90
# 27677         -421           90
# 27678          411           90
# 27679          411           90
# 27680          311          311
#
# [27681 rows x 10 columns]

# %% [markdown]
# - function that evaulates all necessary obseravbles for each event

# %%
def calculate_observables(data):
    events = []
    grouped_data = data.groupby('ievent')

    for ievent, evt in grouped_data:
        # Reset or initialize variables for each event
        e_mu_minus, e_mu_plus, has_charm, e_em, e_visible, ptx, pty, ht = 0, 0, 0, 0, 0, 0, 0, 0
        
        # Iterate over particles in the event
        for _, row in evt.iterrows():
            truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
            parent_pid1 = row[8]
 
                              
            # Check for charm particles
            if abs(parent_pid1) in {411, 421, 431, 4122,15,521,511,531,443,5122,4232,4112,5232}: 
                has_charm = 1
            
            # Update energies for mu- and mu+
            if pid == 13: e_mu_minus = max(e, e_mu_minus)
            elif pid == -13: e_mu_plus = max(e, e_mu_plus)
            
            # Sum EM and visible energy
            if abs(pid) in {22, 11}: 
                e_em += e
            if abs(pid) not in {12, 14, 16}: 
                e_visible += e
                ptx += px
                pty += py
                ht += np.sqrt(px**2 + py**2)
        
        # Calculate missing pT
        pt_mis = -np.sqrt(ptx**2 + pty**2)
        
        # Append event observables
        events.append([ievent, truth_energy, e_mu_minus, e_mu_plus, e_em, has_charm, e_visible, pt_mis, ht])

    # Construct DataFrame from results
    columns = ['ievent', 'truth_energy', 'e_mu_minus', 'e_mu_plus', 'e_em', 'has_charm', 'e_visible', 'pt_mis', 'ht']
    observables = pd.DataFrame(events, columns=columns)
    
    return observables

# %%
# %%time
observables = calculate_observables(data)
# Out:
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# CPU times: user 2.36 s, sys: 23.9 ms, total: 2.38 s
# Wall time: 2.45 s

# %%
observables
# Out:
#       ievent  truth_energy  e_mu_minus  e_mu_plus   e_em  has_charm  \
# 0          1         22.53       0.000      0.488  0.000          1
# 1          2         22.53       1.261      0.324  6.450          0
# 2          3         22.53       0.853      4.620  1.724          1
# 3          4         22.53       1.275      0.539  1.218          0
# 4          5         22.53       0.534      2.197  0.000          1
# ...      ...           ...         ...        ...    ...        ...
# 2363    2364         22.53       0.000      1.484  2.573          1
# 2364    2365         22.53       0.135      0.250  0.398          0
# 2365    2366         22.53       1.190      1.634  1.204          1
# 2366    2367         22.53       0.000      4.545  4.098          1
# 2367    2368         22.53       2.396      3.149  0.000          1
#
#       e_visible    pt_mis        ht
# 0        11.622 -0.775126  2.910989
# 1        21.574 -1.154859  2.556138
# 2        18.463 -1.002941  2.973211
# 3         4.188 -1.296556  1.546107
# 4        16.143 -1.784818  2.795638
# ...         ...       ...       ...
# 2363     19.545 -1.125340  3.060091
# 2364      3.141 -0.623046  0.826662
# 2365     20.523 -0.915495  2.749552
# 2366     15.692 -1.280407  2.987993
# 2367     11.076 -0.234009  1.643491
#
# [2368 rows x 9 columns]

# %%
sns.histplot(observables, x='e_mu_minus')
# Out:
# <Axes: xlabel='e_mu_minus', ylabel='Count'>

# %% [markdown]
# - let us systematically calculate obvservables for all files

# %%
energies = [
    14.21, 17.90, 22.53, 28.37, 35.71, 44.964, 56.60, 71.26, 89.71, 
    112.94, 142.19, 179.00, 225.35, 283.70, 357.16, 449.64, 566.07, 712.64, 897.16,
    1129.46, 1421.90,
] 
#processes = ["CC_numu", "CC_nuebar", "NC_numu", "NC_nuebar","0.125GeV","0.5GeV","1GeV","20GeV"]
processes = ["3.16GeV","7.94GeV","15.84GeV"]
# Loop through all energies
for process in processes: 
    for energy in energies:
        filename = f"output_events_{process}/events_{str(energy)}.csv.zip"
        
        # Check if the file exists
        if not os.path.isfile(filename):
            print(f"File not found: {filename}")
            continue

        print(process, energy)
        data = pd.read_csv(filename)
        
        # Check if DataFrame is empty
        if data.empty:
            print(f"Data is empty for {filename}")
            continue
        
        # Check if 'ievent' column exists
        if 'ievent' not in data.columns:
            print(f"Column 'ievent' not found in {filename}")
            continue
        
        # Check if the first row has a valid value
        if 0 not in data.index or np.isnan(data.loc[0, 'ievent']):
            print(f"Fixing DataFrame for {filename}")
            data = fix_dataframe(data)
        
        # Calculate observables and save
        observables = calculate_observables(data)
        csv_file = f"output_events_{process}/observables_{str(energy)}.csv.zip"
        observables.to_csv(csv_file, index=False, compression='zip')
# Out:
# File not found: output_events_3.16GeV/events_14.21.csv.zip
# File not found: output_events_3.16GeV/events_17.9.csv.zip
# 3.16GeV 22.53
# Data is empty for output_events_3.16GeV/events_22.53.csv.zip
# 3.16GeV 28.37
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 35.71
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 44.964
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 56.6
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 71.26
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 89.71
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 112.94
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 142.19
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 179.0
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 225.35
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 283.7
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 357.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 449.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 566.07
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 712.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 897.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 1129.46
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 3.16GeV 1421.9
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# File not found: output_events_7.94GeV/events_14.21.csv.zip
# File not found: output_events_7.94GeV/events_17.9.csv.zip
# File not found: output_events_7.94GeV/events_22.53.csv.zip
# File not found: output_events_7.94GeV/events_28.37.csv.zip
# File not found: output_events_7.94GeV/events_35.71.csv.zip
# File not found: output_events_7.94GeV/events_44.964.csv.zip
# File not found: output_events_7.94GeV/events_56.6.csv.zip
# 7.94GeV 71.26
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 89.71
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 112.94
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 142.19
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 179.0
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 225.35
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 283.7
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 357.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 449.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 566.07
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 712.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 897.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 1129.46
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 7.94GeV 1421.9
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# File not found: output_events_15.84GeV/events_14.21.csv.zip
# File not found: output_events_15.84GeV/events_17.9.csv.zip
# File not found: output_events_15.84GeV/events_22.53.csv.zip
# File not found: output_events_15.84GeV/events_28.37.csv.zip
# File not found: output_events_15.84GeV/events_35.71.csv.zip
# File not found: output_events_15.84GeV/events_44.964.csv.zip
# File not found: output_events_15.84GeV/events_56.6.csv.zip
# File not found: output_events_15.84GeV/events_71.26.csv.zip
# File not found: output_events_15.84GeV/events_89.71.csv.zip
# File not found: output_events_15.84GeV/events_112.94.csv.zip
# File not found: output_events_15.84GeV/events_142.19.csv.zip
# 15.84GeV 179.0
# Data is empty for output_events_15.84GeV/events_179.0.csv.zip
# 15.84GeV 225.35
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 283.7
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 357.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 449.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 566.07
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 712.64
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 897.16
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 1129.46
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]
# 15.84GeV 1421.9
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_25101/3222167244.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   parent_pid1 = row[8]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Load all events

# %% [markdown]
# Explanation for file format of MC_-14_3TeV_with_cut_with_final.txt: The first column in the file is energy in GeV. The second column is the flux of $\nu_{\mu}$ per year. The third column is the flux of $\bar\nu_{e}$ per year. The remaining columns are for cross sections of the different charged and neutral current processes for $\nu_{\mu}$ and $\bar\nu_{e}$ in units of $cm^{2}$. The cross sections have been obtained using pythia.SigmaGen() and compared with cross-section produced by GENIE. The last two columns correspond to cross section at $\lambda_{\mu\mu}$=1 for the two signals at mass 125MeV and 20 GeV. The cross section has been obtained using MADGRAPH. For the two signals, the flux of incoming neutrinos is considered to be that of $\nu_{\mu}$ as it is the source from which signals originate.

# %% [markdown]
# To get the event weight, we divide the number of interacting neutrinos per year by the number of monte carlo events generated to normalize it.
# \begin{equation}
# N{\nu}_{\mu} =\frac{\sigma\times\rho\times l_{det}\times10^{-36}\times N_{inc}}{m_{p}}
# \end{equation}
#
# Here, $\sigma\times10^{-36}$ is the cross section in $cm^{2}$, $\rho$ is the density of iron in $g/cm^{3}$, $l_{det}$ is the length of detector in centimeters, $N_{inc}$ is the number of incident neutrinos per year and $m_p$ is the mass of proton in gram.

# %%
def load_everything(scaling_file='MC_-14_3TeV_with_cut_with_final.txt',big_det=False):
    
    #initialize numbers
    rho = 7.874            # density of iron in g/cm3
    mass = 1.67e-24        # mass of proton in g
    if big_det:l_det = 4042.54 
    else:l_det = 4.0425 
                         # length of detector for iron for 10 kg in cm
    mul = rho*l_det/mass   # area density, in 1/cm2 

    #initialize output 
    all_data = None
    
    #import data on fluxes and cross sections
    scaling_data = pd.read_csv(scaling_file, delim_whitespace=True) 
    scaling_data['energy'] = round(scaling_data['energy'],0)
    
    #loop over datasets 
    datasets = ['NC_nuebar', 'CC_nuebar', 'CC_numu', 'NC_numu',"0.125GeV","0.5GeV","1GeV","3.16GeV","7.94GeV","15.84GeV","20GeV"]
    
    for dataset in datasets:
        
        # get all files and loop over them
        dirname = 'output_events_' + dataset  
        directory = pathlib.Path(dirname)
        files = sorted(directory.rglob('observables_*.csv.zip'))
        
        #import data on generated event rates
        generated_data_name = dirname+"/generated_events.json"
        with open(generated_data_name, "r") as f: generated_data_raw = json.load(f)
        generated_data = {int(float(key)): value for key, value in generated_data_raw.items()}

        for file in files:
            #logging
            #print("load file: "+ str(file))
            
            # get beam energy
            energy = float(str(file).split('_')[-1].replace('.csv.zip', ''))
                
            # load data, get observables
            observables = pd.read_csv(str(file))
            observables['set'] = dataset
            print("load file: "+ str(file), len(observables))
            
            ### obtain number of events (allows for different nevents for different energies)
            nevent = generated_data[int(energy)]
            
            # calculate scaling factor            
            scaling_row = scaling_data[scaling_data['energy'] == round(energy,0)]
            
            cross_section = scaling_row[dataset].values[0]
            if dataset in ["0.125GeV","0.5GeV","1GeV","3.16GeV","7.94GeV","15.84GeV","20GeV"]:flux = scaling_row["numu"+"_flux"].values[0]
            else:flux = scaling_row[dataset[3:]+"_flux"].values[0]
            #flux = scaling_row[dataset[3:]+"_flux"].values[0]  
            weight = ((cross_section * flux * mul)/nevent)    
            observables['weight'] = weight
            
            # combine data
            if all_data is None: all_data = observables
            else:all_data = pd.concat([all_data, observables])
    
    return all_data.reset_index(drop=True)

# %%
data0 = load_everything(scaling_file='MC_-14_3TeV_with_cut_with_final_output.txt',big_det=True)
# Out:
# load file: output_events_NC_nuebar/observables_112.94.csv.zip 15598
# load file: output_events_NC_nuebar/observables_1129.46.csv.zip 119176
# load file: output_events_NC_nuebar/observables_14.21.csv.zip 1162
# load file: output_events_NC_nuebar/observables_142.19.csv.zip 18674
# load file: output_events_NC_nuebar/observables_1421.9.csv.zip 130966
# load file: output_events_NC_nuebar/observables_17.9.csv.zip 1838
# load file: output_events_NC_nuebar/observables_179.0.csv.zip 21699
# load file: output_events_NC_nuebar/observables_22.53.csv.zip 2717
# load file: output_events_NC_nuebar/observables_225.35.csv.zip 25585
# load file: output_events_NC_nuebar/observables_28.37.csv.zip 3673
# load file: output_events_NC_nuebar/observables_283.7.csv.zip 29544
# load file: output_events_NC_nuebar/observables_35.71.csv.zip 4919
# load file: output_events_NC_nuebar/observables_357.16.csv.zip 33655
# load file: output_events_NC_nuebar/observables_44.964.csv.zip 6642
# load file: output_events_NC_nuebar/observables_449.64.csv.zip 37884
# load file: output_events_NC_nuebar/observables_56.6.csv.zip 8320
# load file: output_events_NC_nuebar/observables_566.07.csv.zip 43302
# load file: output_events_NC_nuebar/observables_71.26.csv.zip 10421
# load file: output_events_NC_nuebar/observables_712.64.csv.zip 48411
# load file: output_events_NC_nuebar/observables_89.71.csv.zip 12828
# load file: output_events_NC_nuebar/observables_897.16.csv.zip 54235
# load file: output_events_CC_nuebar/observables_112.94.csv.zip 1415
# load file: output_events_CC_nuebar/observables_1129.46.csv.zip 6397
# load file: output_events_CC_nuebar/observables_14.21.csv.zip 509
# load file: output_events_CC_nuebar/observables_142.19.csv.zip 1439
# load file: output_events_CC_nuebar/observables_1421.9.csv.zip 7092
# load file: output_events_CC_nuebar/observables_17.9.csv.zip 597
# load file: output_events_CC_nuebar/observables_179.0.csv.zip 1601
# load file: output_events_CC_nuebar/observables_22.53.csv.zip 706
# load file: output_events_CC_nuebar/observables_225.35.csv.zip 1772
# load file: output_events_CC_nuebar/observables_28.37.csv.zip 742
# load file: output_events_CC_nuebar/observables_283.7.csv.zip 1907
# load file: output_events_CC_nuebar/observables_35.71.csv.zip 844
# load file: output_events_CC_nuebar/observables_357.16.csv.zip 2030
# load file: output_events_CC_nuebar/observables_44.964.csv.zip 935
# load file: output_events_CC_nuebar/observables_449.64.csv.zip 2174
# load file: output_events_CC_nuebar/observables_56.6.csv.zip 1048
# load file: output_events_CC_nuebar/observables_566.07.csv.zip 2464
# load file: output_events_CC_nuebar/observables_71.26.csv.zip 1120
# load file: output_events_CC_nuebar/observables_712.64.csv.zip 2580
# load file: output_events_CC_nuebar/observables_89.71.csv.zip 1242
# load file: output_events_CC_nuebar/observables_897.16.csv.zip 2919
# load file: output_events_CC_numu/observables_112.94.csv.zip 102377
# load file: output_events_CC_numu/observables_1129.46.csv.zip 266739
# load file: output_events_CC_numu/observables_14.21.csv.zip 59683
# load file: output_events_CC_numu/observables_142.19.csv.zip 105306
# load file: output_events_CC_numu/observables_1421.9.csv.zip 273801
# load file: output_events_CC_numu/observables_17.9.csv.zip 66597
# load file: output_events_CC_numu/observables_179.0.csv.zip 109818
# load file: output_events_CC_numu/observables_22.53.csv.zip 73040
# load file: output_events_CC_numu/observables_225.35.csv.zip 111760
# load file: output_events_CC_numu/observables_28.37.csv.zip 77424
# load file: output_events_CC_numu/observables_283.7.csv.zip 115642
# load file: output_events_CC_numu/observables_35.71.csv.zip 82520
# load file: output_events_CC_numu/observables_357.16.csv.zip 118006
# load file: output_events_CC_numu/observables_44.964.csv.zip 87501
# load file: output_events_CC_numu/observables_449.64.csv.zip 121475
# load file: output_events_CC_numu/observables_56.6.csv.zip 91757
# load file: output_events_CC_numu/observables_566.07.csv.zip 123949
# load file: output_events_CC_numu/observables_71.26.csv.zip 94733
# load file: output_events_CC_numu/observables_712.64.csv.zip 128177
# load file: output_events_CC_numu/observables_89.71.csv.zip 98739
# load file: output_events_CC_numu/observables_897.16.csv.zip 130459
# load file: output_events_NC_numu/observables_112.94.csv.zip 10487
# load file: output_events_NC_numu/observables_1129.46.csv.zip 75754
# load file: output_events_NC_numu/observables_14.21.csv.zip 1018
# load file: output_events_NC_numu/observables_142.19.csv.zip 12283
# load file: output_events_NC_numu/observables_1421.9.csv.zip 84272
# load file: output_events_NC_numu/observables_17.9.csv.zip 1604
# load file: output_events_NC_numu/observables_179.0.csv.zip 14433
# load file: output_events_NC_numu/observables_22.53.csv.zip 2368
# load file: output_events_NC_numu/observables_225.35.csv.zip 16530
# load file: output_events_NC_numu/observables_28.37.csv.zip 3112
# load file: output_events_NC_numu/observables_283.7.csv.zip 19022
# load file: output_events_NC_numu/observables_35.71.csv.zip 4071
# load file: output_events_NC_numu/observables_357.16.csv.zip 21537
# load file: output_events_NC_numu/observables_44.964.csv.zip 4899
# load file: output_events_NC_numu/observables_449.64.csv.zip 24436
# load file: output_events_NC_numu/observables_56.6.csv.zip 6129
# load file: output_events_NC_numu/observables_566.07.csv.zip 27249
# load file: output_events_NC_numu/observables_71.26.csv.zip 7344
# load file: output_events_NC_numu/observables_712.64.csv.zip 30492
# load file: output_events_NC_numu/observables_89.71.csv.zip 8971
# load file: output_events_NC_numu/observables_897.16.csv.zip 34168
# load file: output_events_0.125GeV/observables_112.94.csv.zip 9997
# load file: output_events_0.125GeV/observables_1129.46.csv.zip 10000
# load file: output_events_0.125GeV/observables_14.21.csv.zip 683
# load file: output_events_0.125GeV/observables_142.19.csv.zip 9998
# load file: output_events_0.125GeV/observables_1421.9.csv.zip 10000
# load file: output_events_0.125GeV/observables_17.9.csv.zip 6229
# load file: output_events_0.125GeV/observables_179.0.csv.zip 9999
# load file: output_events_0.125GeV/observables_22.53.csv.zip 8668
# load file: output_events_0.125GeV/observables_225.35.csv.zip 10000
# load file: output_events_0.125GeV/observables_28.37.csv.zip 9504
# load file: output_events_0.125GeV/observables_283.7.csv.zip 10000
# load file: output_events_0.125GeV/observables_35.71.csv.zip 9792
# load file: output_events_0.125GeV/observables_357.16.csv.zip 10000
# load file: output_events_0.125GeV/observables_44.964.csv.zip 9922
# load file: output_events_0.125GeV/observables_449.64.csv.zip 10000
# load file: output_events_0.125GeV/observables_56.6.csv.zip 9963
# load file: output_events_0.125GeV/observables_566.07.csv.zip 10000
# load file: output_events_0.125GeV/observables_71.26.csv.zip 9979
# load file: output_events_0.125GeV/observables_712.64.csv.zip 10000
# load file: output_events_0.125GeV/observables_89.71.csv.zip 9991
# load file: output_events_0.125GeV/observables_897.16.csv.zip 10000
# load file: output_events_0.5GeV/observables_112.94.csv.zip 9996
# load file: output_events_0.5GeV/observables_1129.46.csv.zip 10000
# load file: output_events_0.5GeV/observables_14.21.csv.zip 94
# load file: output_events_0.5GeV/observables_142.19.csv.zip 9998
# load file: output_events_0.5GeV/observables_1421.9.csv.zip 10000
# load file: output_events_0.5GeV/observables_17.9.csv.zip 5442
# load file: output_events_0.5GeV/observables_179.0.csv.zip 10000
# load file: output_events_0.5GeV/observables_22.53.csv.zip 8482
# load file: output_events_0.5GeV/observables_225.35.csv.zip 10000
# load file: output_events_0.5GeV/observables_28.37.csv.zip 9438
# load file: output_events_0.5GeV/observables_283.7.csv.zip 10000
# load file: output_events_0.5GeV/observables_35.71.csv.zip 9784
# load file: output_events_0.5GeV/observables_357.16.csv.zip 10000
# load file: output_events_0.5GeV/observables_44.964.csv.zip 9929
# load file: output_events_0.5GeV/observables_449.64.csv.zip 9998
# load file: output_events_0.5GeV/observables_56.6.csv.zip 9965
# load file: output_events_0.5GeV/observables_566.07.csv.zip 10000
# load file: output_events_0.5GeV/observables_71.26.csv.zip 9986
# load file: output_events_0.5GeV/observables_712.64.csv.zip 10000
# load file: output_events_0.5GeV/observables_89.71.csv.zip 9992
# load file: output_events_0.5GeV/observables_897.16.csv.zip 10000
# load file: output_events_1GeV/observables_112.94.csv.zip 9997
# load file: output_events_1GeV/observables_1129.46.csv.zip 10000
# load file: output_events_1GeV/observables_142.19.csv.zip 9996
# load file: output_events_1GeV/observables_1421.9.csv.zip 10000
# load file: output_events_1GeV/observables_17.9.csv.zip 3229
# load file: output_events_1GeV/observables_179.0.csv.zip 9998
# load file: output_events_1GeV/observables_22.53.csv.zip 7768
# load file: output_events_1GeV/observables_225.35.csv.zip 9998
# load file: output_events_1GeV/observables_28.37.csv.zip 9249
# load file: output_events_1GeV/observables_283.7.csv.zip 9999
# load file: output_events_1GeV/observables_35.71.csv.zip 9765
# load file: output_events_1GeV/observables_357.16.csv.zip 10000
# load file: output_events_1GeV/observables_44.964.csv.zip 9896
# load file: output_events_1GeV/observables_449.64.csv.zip 10000
# load file: output_events_1GeV/observables_56.6.csv.zip 9954
# load file: output_events_1GeV/observables_566.07.csv.zip 10000
# load file: output_events_1GeV/observables_71.26.csv.zip 9980
# load file: output_events_1GeV/observables_712.64.csv.zip 10000
# load file: output_events_1GeV/observables_89.71.csv.zip 9992
# load file: output_events_1GeV/observables_897.16.csv.zip 10000
# load file: output_events_3.16GeV/observables_112.94.csv.zip 9991
# load file: output_events_3.16GeV/observables_1129.46.csv.zip 10000
# load file: output_events_3.16GeV/observables_142.19.csv.zip 9996
# load file: output_events_3.16GeV/observables_1421.9.csv.zip 10000
# load file: output_events_3.16GeV/observables_179.0.csv.zip 9997
# load file: output_events_3.16GeV/observables_225.35.csv.zip 9998
# load file: output_events_3.16GeV/observables_28.37.csv.zip 2474
# load file: output_events_3.16GeV/observables_283.7.csv.zip 9999
# load file: output_events_3.16GeV/observables_35.71.csv.zip 7745
# load file: output_events_3.16GeV/observables_357.16.csv.zip 10000
# load file: output_events_3.16GeV/observables_44.964.csv.zip 9394
# load file: output_events_3.16GeV/observables_449.64.csv.zip 10000
# load file: output_events_3.16GeV/observables_56.6.csv.zip 9811
# load file: output_events_3.16GeV/observables_566.07.csv.zip 10000
# load file: output_events_3.16GeV/observables_71.26.csv.zip 9942
# load file: output_events_3.16GeV/observables_712.64.csv.zip 10000
# load file: output_events_3.16GeV/observables_89.71.csv.zip 9984
# load file: output_events_3.16GeV/observables_897.16.csv.zip 9999
# load file: output_events_7.94GeV/observables_112.94.csv.zip 9776
# load file: output_events_7.94GeV/observables_1129.46.csv.zip 10000
# load file: output_events_7.94GeV/observables_142.19.csv.zip 9952
# load file: output_events_7.94GeV/observables_1421.9.csv.zip 10000
# load file: output_events_7.94GeV/observables_179.0.csv.zip 9982
# load file: output_events_7.94GeV/observables_225.35.csv.zip 9994
# load file: output_events_7.94GeV/observables_283.7.csv.zip 9999
# load file: output_events_7.94GeV/observables_357.16.csv.zip 10000
# load file: output_events_7.94GeV/observables_449.64.csv.zip 10000
# load file: output_events_7.94GeV/observables_566.07.csv.zip 10000
# load file: output_events_7.94GeV/observables_71.26.csv.zip 1025
# load file: output_events_7.94GeV/observables_712.64.csv.zip 10000
# load file: output_events_7.94GeV/observables_89.71.csv.zip 8622
# load file: output_events_7.94GeV/observables_897.16.csv.zip 10000
# load file: output_events_15.84GeV/observables_1129.46.csv.zip 10000
# load file: output_events_15.84GeV/observables_1421.9.csv.zip 10000
# load file: output_events_15.84GeV/observables_225.35.csv.zip 8169
# load file: output_events_15.84GeV/observables_283.7.csv.zip 9884
# load file: output_events_15.84GeV/observables_357.16.csv.zip 9981
# load file: output_events_15.84GeV/observables_449.64.csv.zip 9991
# load file: output_events_15.84GeV/observables_566.07.csv.zip 9999
# load file: output_events_15.84GeV/observables_712.64.csv.zip 9999
# load file: output_events_15.84GeV/observables_897.16.csv.zip 10000
# load file: output_events_20GeV/observables_1129.46.csv.zip 10000
# load file: output_events_20GeV/observables_1421.9.csv.zip 10000
# load file: output_events_20GeV/observables_357.16.csv.zip 9578
# load file: output_events_20GeV/observables_449.64.csv.zip 9970
# load file: output_events_20GeV/observables_566.07.csv.zip 9992
# load file: output_events_20GeV/observables_712.64.csv.zip 10000
# load file: output_events_20GeV/observables_897.16.csv.zip 10000

# %% [markdown]
# ### Get event rates and histograms after cuts

# %% [markdown]
# - function that prints

# %%
         
def get_rates(data, header=None):
    # Print header if provided
    if header is not None: 
        print(header + ":")

    # Initialize counters for the combined total
    total_background_real = 0
    total_background_mc = 0
    # Store signal results
    signals = {}
    # Get event rates and MC statistics for all processes
    for dataset in ['CC_numu', 'CC_nuebar', 'NC_numu', 'NC_nuebar', "0.125GeV", "0.5GeV", "1GeV", "3.16GeV", "7.94GeV", "15.84GeV", "20GeV"]:
        n_mc = len(data[data['set'] == dataset])
        n_real = sum(data[data['set'] == dataset]['weight'])        
        # Add to the combined background total
        if "CC" in dataset or "NC" in dataset:
            total_background_real += n_real
            total_background_mc += n_mc
        else:
            signals[dataset] = n_real

        # Print dataset-specific rates
        print(f"   {dataset}: {n_real} (N_MC = {n_mc})")    
    # Print combined background total
    print(f"\nTotal Background events: {total_background_real} (N_MC = {total_background_mc})")    
    
    # Calculate and print Signal/√Background for each signal dataset
    if total_background_real > 0:
        signal_threshold = 2 * (total_background_real**0.5)
        print(f"\nSignal required for S/√B > 2: {signal_threshold:.3f}")
        print("\nSignal/√Background for each signal dataset (with Signal > 3):")
        print("Coupling adjustments to meet S/√B > 2:")

        for signal, n_real in signals.items():
            if n_real > 3:
                # Signal-to-background ratio
                ratio = n_real / (total_background_real**0.5)
                if ratio > 2:
                    print(f"   {signal}: {ratio:.3f}")
                    
                    # Required coupling scaling factor
                    scaling_factor = (signal_threshold / n_real)**0.5
                    print(f"      Coupling scaling factor for {signal}: {scaling_factor:.3f}")
                else:
                    print(f"   {signal}: Signal/√Background = {ratio:.3f}, does not meet the threshold.")
            else:
                print(f"   {signal}: Signal = {n_real}, does not meet the minimum threshold of 3.")
    else:
        print("\nBackground events are zero; cannot compute Signal/√Background.")


def get_stacked_histogram(data, observable, bins, xlabel, xlog=False):
               
    # setup figure
    datasets = {'CC_numu':"dodgerblue", 'CC_nuebar':"blue", 'NC_numu':"red", 'NC_nuebar':"firebrick",'0.125GeV':"forestgreen",'20GeV':"darkgreen"}
    labels = {'CC_numu':r"CC $\nu_\mu$", 'CC_nuebar':r"CC $\nu_e$", 'NC_numu':r"NC $\nu_\mu$", 'NC_nuebar':r"NC $\nu_e$",'0.125GeV':r"Signal 125MeV",'20GeV':r"Signal 20GeV"}
    matplotlib.rcParams.update({'font.size': 14})
    matplotlib.rcParams['text.usetex'] = False
    fig = plt.figure(figsize=(12,4.5))
    
    #plot linear 
    ax1 = plt.subplot(1,2,1)   
    ax2 = plt.subplot(1,2,2)   
    for dataset in datasets.keys():
        
        #get stuff
        subset = data[data['set']==dataset]
        x, w = subset[observable], subset['weight']
        c, l = datasets[dataset], labels[dataset]
        # Set transparency for signal datasets
        alpha = 0.4 if 'GeV' in dataset else 1.0
        # linear y-axis   
        ax1.hist(x, weights=w, histtype='bar', stacked=True, bins=bins, color=c, label = l,alpha=alpha)
        
        # log y axis
        ax2.hist(x, weights=w, histtype='bar', stacked=True, bins=bins, color=c, label = l,alpha=alpha)
    
    # linear y-axis           
    if xlog: ax1.set_xscale("log")
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(r"Interacting Neutrinos")
    ax1.legend(frameon=False, labelspacing=0, fontsize=14)
          
    # log y axis     
    if xlog: ax2.set_xscale("log")
    ax2.set_yscale("log")
    ax2.set_xlabel(xlabel)
    ax2.set_ylabel(r"Interacting Neutrinos")
    ax2.legend(frameon=False, labelspacing=0, fontsize=14)
         
    #finalize
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 1.  select data with mu+ with E>100GeV

# %%
data = data0.copy()
get_stacked_histogram(
    data=data, 
    observable="e_mu_plus", 
    bins=np.logspace(1,3.5,25+1), 
    xlabel="Mu_plus Energy [GeV]", 
    xlog=True,
)

# %%
data = data[data['e_mu_plus']>500]
get_rates(data, header = r"Events with $E_{\mu^+} >200$ GeV")
# Out:
# Events with $E_{\mu^+} >200$ GeV:
#    CC_numu: 292548.09777874005 (N_MC = 4150)
#    CC_nuebar: 641.9959515073512 (N_MC = 28)
#    NC_numu: 13559.852346746575 (N_MC = 618)
#    NC_nuebar: 6162.363379877801 (N_MC = 1207)
#    0.125GeV: 324718.9234017035 (N_MC = 8511)
#    0.5GeV: 305455.5116365609 (N_MC = 8061)
#    1GeV: 292509.8792114541 (N_MC = 7767)
#    3.16GeV: 247190.7026543874 (N_MC = 6723)
#    7.94GeV: 159504.20545407652 (N_MC = 4624)
#    15.84GeV: 56101.07939494128 (N_MC = 1978)
#    20GeV: 26322.913388316945 (N_MC = 1042)
#
# Total Background events: 312912.3094568718 (N_MC = 6003)
#
# Signal required for S/√B > 2: 1118.771
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: 580.492
#       Coupling scaling factor for 0.125GeV: 0.059
#    0.5GeV: 546.055
#       Coupling scaling factor for 0.5GeV: 0.061
#    1GeV: 522.913
#       Coupling scaling factor for 1GeV: 0.062
#    3.16GeV: 441.897
#       Coupling scaling factor for 3.16GeV: 0.067
#    7.94GeV: 285.142
#       Coupling scaling factor for 7.94GeV: 0.084
#    15.84GeV: 100.291
#       Coupling scaling factor for 15.84GeV: 0.141
#    20GeV: 47.057
#       Coupling scaling factor for 20GeV: 0.206

# %% [markdown]
# ### 2. Veto events with mu- with E<10 GeV

# %%
get_stacked_histogram(
    data=data, 
    observable="e_mu_minus", 
    bins=np.logspace(1,3.5,25+1), 
    xlabel="Mu- Energy [GeV]", 
    xlog=True,
)

# %%
data = data[data['e_mu_minus']<10]
get_rates(data, header = r"Events with $E_{\mu^-} <10$ GeV")
# Out:
# Events with $E_{\mu^-} <10$ GeV:
#    CC_numu: 10537.504016651068 (N_MC = 125)
#    CC_nuebar: 0 (N_MC = 0)
#    NC_numu: 11891.30754862421 (N_MC = 541)
#    NC_nuebar: 5101.658810781078 (N_MC = 998)
#    0.125GeV: 323358.8642083821 (N_MC = 8471)
#    0.5GeV: 304162.894833532 (N_MC = 8028)
#    1GeV: 291597.81283204106 (N_MC = 7739)
#    3.16GeV: 246733.4502938362 (N_MC = 6709)
#    7.94GeV: 159348.05331115358 (N_MC = 4618)
#    15.84GeV: 56101.07939494128 (N_MC = 1978)
#    20GeV: 26322.913388316945 (N_MC = 1042)
#
# Total Background events: 27530.470376056357 (N_MC = 1664)
#
# Signal required for S/√B > 2: 331.846
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: 1948.848
#       Coupling scaling factor for 0.125GeV: 0.032
#    0.5GeV: 1833.156
#       Coupling scaling factor for 0.5GeV: 0.033
#    1GeV: 1757.428
#       Coupling scaling factor for 1GeV: 0.034
#    3.16GeV: 1487.035
#       Coupling scaling factor for 3.16GeV: 0.037
#    7.94GeV: 960.373
#       Coupling scaling factor for 7.94GeV: 0.046
#    15.84GeV: 338.115
#       Coupling scaling factor for 15.84GeV: 0.077
#    20GeV: 158.645
#       Coupling scaling factor for 20GeV: 0.112

# %% [markdown]
# ### 3. EM energy

# %%
get_stacked_histogram(
    data=data, 
    observable="e_em", 
    bins=np.logspace(1,3.5,25+1), 
    xlabel="EM Energy [GeV]", 
    xlog=True,
)

# %%
data = data[data['e_em']<100]
get_rates(data, header = r"Events with $E_EM <100$ GeV")
# Out:
# Events with $E_EM <100$ GeV:
#    CC_numu: 5469.66611784417 (N_MC = 61)
#    CC_nuebar: 0 (N_MC = 0)
#    NC_numu: 6733.784831026153 (N_MC = 289)
#    NC_nuebar: 2206.588265650726 (N_MC = 359)
#    0.125GeV: 276696.7381231135 (N_MC = 7039)
#    0.5GeV: 260043.1880834212 (N_MC = 6658)
#    1GeV: 243521.60019707336 (N_MC = 6264)
#    3.16GeV: 201797.3642073713 (N_MC = 5293)
#    7.94GeV: 128435.74526982478 (N_MC = 3591)
#    15.84GeV: 46640.83681347981 (N_MC = 1592)
#    20GeV: 23246.97533990088 (N_MC = 901)
#
# Total Background events: 14410.039214521048 (N_MC = 709)
#
# Signal required for S/√B > 2: 240.084
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: 2305.003
#       Coupling scaling factor for 0.125GeV: 0.029
#    0.5GeV: 2166.272
#       Coupling scaling factor for 0.5GeV: 0.030
#    1GeV: 2028.640
#       Coupling scaling factor for 1GeV: 0.031
#    3.16GeV: 1681.059
#       Coupling scaling factor for 3.16GeV: 0.034
#    7.94GeV: 1069.925
#       Coupling scaling factor for 7.94GeV: 0.043
#    15.84GeV: 388.538
#       Coupling scaling factor for 15.84GeV: 0.072
#    20GeV: 193.657
#       Coupling scaling factor for 20GeV: 0.102

# %% [markdown]
# ### 4. Charm Veto

# %%
veto_prob = 0.8
data.loc[:, 'random'] = np.random.random(data.shape[0])
data = data[(data['has_charm']==1) & (data['random']<veto_prob)]
get_rates(data, header = r"Events without charm")
# Out:
# Events without charm:
#    CC_numu: 4345.181608801506 (N_MC = 49)
#    CC_nuebar: 0 (N_MC = 0)
#    NC_numu: 5634.378834997849 (N_MC = 243)
#    NC_nuebar: 1773.822149046753 (N_MC = 290)
#    0.125GeV: 11962.105639302135 (N_MC = 327)
#    0.5GeV: 9035.504972259956 (N_MC = 246)
#    1GeV: 8374.164037595849 (N_MC = 220)
#    3.16GeV: 3764.600068320612 (N_MC = 110)
#    7.94GeV: 1183.6273282897957 (N_MC = 38)
#    15.84GeV: 40.74333696911692 (N_MC = 2)
#    20GeV: 61.11500545367538 (N_MC = 3)
#
# Total Background events: 11753.382592846106 (N_MC = 582)
#
# Signal required for S/√B > 2: 216.826
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: 110.338
#       Coupling scaling factor for 0.125GeV: 0.135
#    0.5GeV: 83.343
#       Coupling scaling factor for 0.5GeV: 0.155
#    1GeV: 77.243
#       Coupling scaling factor for 1GeV: 0.161
#    3.16GeV: 34.725
#       Coupling scaling factor for 3.16GeV: 0.240
#    7.94GeV: 10.918
#       Coupling scaling factor for 7.94GeV: 0.428
#    15.84GeV: Signal/√Background = 0.376, does not meet the threshold.
#    20GeV: Signal/√Background = 0.564, does not meet the threshold.
# /var/folders/rs/w38byv0x4wlcgrjkdwx6rm_c0000gp/T/ipykernel_1128/343797983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, 'random'] = np.random.random(data.shape[0])

# %%
data = data[data['e_visible']<600]
get_rates(data, header = r"Events with $E_visible <500$ GeV")
# Out:
# Events with $E_visible <500$ GeV:
#    CC_numu: 5818.585989297433 (N_MC = 33)
#    CC_nuebar: 0 (N_MC = 0)
#    NC_numu: 5947.977827958619 (N_MC = 122)
#    NC_nuebar: 3528.909548451059 (N_MC = 158)
#    0.125GeV: 2075.405230243685 (N_MC = 66)
#    0.5GeV: 1182.1552982264316 (N_MC = 36)
#    1GeV: 865.0088428465731 (N_MC = 26)
#    3.16GeV: 379.2478055551397 (N_MC = 11)
#    7.94GeV: 34.477073232285434 (N_MC = 1)
#    15.84GeV: 0 (N_MC = 0)
#    20GeV: 0 (N_MC = 0)
#
# Total Background events: 15295.473365707112 (N_MC = 313)
#
# Signal required for S/√B > 2: 247.350
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: 16.781
#       Coupling scaling factor for 0.125GeV: 0.345
#    0.5GeV: 9.559
#       Coupling scaling factor for 0.5GeV: 0.457
#    1GeV: 6.994
#       Coupling scaling factor for 1GeV: 0.535
#    3.16GeV: 3.066
#       Coupling scaling factor for 3.16GeV: 0.808
#    7.94GeV: Signal/√Background = 0.279, does not meet the threshold.
#    15.84GeV: Signal = 0, does not meet the minimum threshold of 3.
#    20GeV: Signal = 0, does not meet the minimum threshold of 3.

# %%
data = data[abs(data['pt_mis']) >1]
get_rates(data, header = r"Events with $pt_missing >3$ GeV")
# Out:
# Events with $pt_missing >3$ GeV:
#    CC_numu: 294.600815052505 (N_MC = 2)
#    CC_nuebar: 0 (N_MC = 0)
#    NC_numu: 5557.384490151834 (N_MC = 116)
#    NC_nuebar: 3216.7324018079844 (N_MC = 146)
#    0.125GeV: 172.9695127361428 (N_MC = 5)
#    0.5GeV: 68.95414646457087 (N_MC = 2)
#    1GeV: 14.885879666606295 (N_MC = 1)
#    3.16GeV: 0 (N_MC = 0)
#    7.94GeV: 0 (N_MC = 0)
#    15.84GeV: 0 (N_MC = 0)
#    20GeV: 0 (N_MC = 0)
#
# Total Background events: 9068.717707012323 (N_MC = 264)
#
# Signal required for S/√B > 2: 190.460
#
# Signal/√Background for each signal dataset (with Signal > 3):
# Coupling adjustments to meet S/√B > 2:
#    0.125GeV: Signal/√Background = 1.816, does not meet the threshold.
#    0.5GeV: Signal/√Background = 0.724, does not meet the threshold.
#    1GeV: Signal/√Background = 0.156, does not meet the threshold.
#    3.16GeV: Signal = 0, does not meet the minimum threshold of 3.
#    7.94GeV: Signal = 0, does not meet the minimum threshold of 3.
#    15.84GeV: Signal = 0, does not meet the minimum threshold of 3.
#    20GeV: Signal = 0, does not meet the minimum threshold of 3.
