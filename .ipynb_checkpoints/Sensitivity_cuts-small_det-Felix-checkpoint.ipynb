# %% [markdown]
# # Project: Neutrino Portal at the Muon Collider

# %% [markdown]
# ## Load Libraries

# %%
import os
import pandas as pd
import numpy as np
import pathlib
import ast
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %% [markdown]
# ## Load Events

# %% [markdown]
# -  this function reads the particles in a csv file and exports a data frame

# %%
data= pd.read_csv('output_events_CC_numu/events_112.94.csv.zip')

# %%
data
# Out:
#      ievent  iparticle  truth_energy   pid     px     py      pz       e  \
# 0        12          0        112.94    13 -0.636  1.241  81.198  81.210
# 1        12          1        112.94  2212  0.327 -0.392   1.815   2.106
# 2        12          2        112.94   -13  0.103  0.687   5.687   5.730
# 3        12          3        112.94    14  0.374 -0.157   3.223   3.248
# 4        12          4        112.94    22 -0.205  0.073   2.072   2.083
# ..      ...        ...           ...   ...    ...    ...     ...     ...
# 136     980         11        112.94    22  0.048 -0.035   0.904   0.906
# 137     980         12        112.94    22  0.271 -0.007   1.065   1.099
# 138     980         13        112.94    22  0.078 -0.048   0.708   0.714
# 139     980         14        112.94   211  1.329 -0.284  10.095  10.187
# 140     980         15        112.94  -211  0.732 -0.472   7.213   7.267
#
#      parent_pid1  parent_pid2
# 0             14            1
# 1           2214           90
# 2            411           90
# 3            411           90
# 4            111           90
# ..           ...          ...
# 136          111           90
# 137          111           90
# 138          111           90
# 139          310           90
# 140          310           90
#
# [141 rows x 10 columns]

# %% [markdown]
# - function that evaulates all necessary obseravbles for each event

# %%
def calculate_observables(data):
    events = []
    grouped_data = data.groupby('ievent')

    for ievent, evt in grouped_data:
        # Reset or initialize variables for each event
        e_mu_minus, e_mu_plus, has_charm, e_em, e_visible, ptx, pty, ht = 0, 0, 0, 0, 0, 0, 0, 0
        
        # Iterate over particles in the event
        for _, row in evt.iterrows():
            truth_energy, pid, px, py, pz, e  = row[2], row[3], row[4], row[5], row[6], row[7]
            parent_pid1 = row[8]
            
            # Check for charm particles
            if abs(parent_pid1) in {411, 421, 431, 4122}: 
                has_charm = 1
            
            # Update energies for mu- and mu+
            if pid == 13: e_mu_minus = max(e, e_mu_minus)
            elif pid == -13: e_mu_plus = max(e, e_mu_plus)
            
            # Sum EM and visible energy
            if abs(pid) in {22, 11}: 
                e_em += e
            if abs(pid) not in {12, 14, 16}: 
                e_visible += e
                ptx += px
                pty += py
                ht += np.sqrt(px**2 + py**2)
        
        # Calculate missing pT
        pt_mis = -np.sqrt(ptx**2 + pty**2)
        
        # Append event observables
        events.append([ievent, truth_energy, e_mu_minus, e_mu_plus, has_charm, e_visible, pt_mis, ht])

    # Construct DataFrame from results
    columns = ['ievent', 'truth_energy', 'e_mu_minus', 'e_mu_plus', 'has_charm', 'e_visible', 'pt_mis', 'ht']
    observables = pd.DataFrame(events, columns=columns)
    
    return observables

# %%
# %%time
observables = calculate_observables(data)
# Out:
# CPU times: user 21.3 ms, sys: 2.34 ms, total: 23.6 ms
# Wall time: 23.8 ms

# %%
observables
# Out:
#     ievent  truth_energy  e_mu_minus  e_mu_plus  has_charm  e_visible  \
# 0       12        112.94      81.210      5.730          1    110.648
# 1       23        112.94      10.830     38.103          1     82.346
# 2      190        112.94      82.386      5.235          1    108.225
# 3      513        112.94      14.305      4.225          1     96.296
# 4      544        112.94      98.310      5.743          1    109.675
# 5      649        112.94      65.448      6.099          1    108.004
# 6      809        112.94      68.781      4.140          1    101.986
# 7      940        112.94     109.014      0.337          1    112.515
# 8      959        112.94      84.630     10.361          1    108.026
# 9      976        112.94      19.693     15.947          1    108.140
# 10     980        112.94      80.577      0.216          1    113.694
#
#       pt_mis        ht
# 0  -0.404695  5.280341
# 1  -1.076315  7.156739
# 2  -0.524742  5.183489
# 3  -0.091285  8.005864
# 4  -0.695690  3.864772
# 5  -0.996653  9.203202
# 6  -1.182153  6.363910
# 7  -0.343390  2.345751
# 8  -0.959785  4.355819
# 9  -0.327075  4.829442
# 10 -0.093408  8.158756

# %%
sns.histplot(observables, x='e_mu_minus')
# Out:
# <AxesSubplot:xlabel='e_mu_minus', ylabel='Count'>

# %% [markdown]
# - load all events

# %% [markdown]
# **Add explaination for file format of MC_-14_3TeV_with_cut_with_final.txt: please explain what the new file MC_-14_3TeV_with_cut_with_final.txt contains. (including units, and where these numbers come from)**

# %% [markdown]
# **Explain how the weights are calculated (so type some formulas, references, ...)**

# %%
def load_everything(scaling_file='MC_-14_3TeV_with_cut_with_final.txt'):
    
    #initialize numbers
    rho = 7.874            # density of iron in g/cm3
    mass = 1.67e-24        # mass of proton in g 
    l_det = 4.0425         # length of detector for iron for 10 kg in cm
    mul = rho*l_det/mass   # area density, in 1/cm2
    nevent = 1e7           # No. of MC events 

    #initialize output 
    all_data = None
    
    #import data on fluxes and cross sections
    scaling_data = pd.read_csv(scaling_file, delim_whitespace=True) 
    scaling_data['energy'] = round(scaling_data['energy'],0)
    
    #loop over datasets 
    datasets = ['NC_nuebar', 'CC_nuebar', 'CC_numu', 'NC_numu']
    for dataset in datasets:
        
        # get all files and loop over them
        dirname = 'output_events_' + dataset  
        directory = pathlib.Path(dirname)
        files = sorted(directory.rglob('events_*.csv.zip'))
        
        #import data on generated event rates
        generated_data_name = dirname+"/generated_events.json"
        with open(generated_data_name, "r") as f: generated_data_raw = json.load(f)
        generated_data = {int(float(key)): value for key, value in generated_data_raw.items()}

        for file in files:
            #logging
            print("load file: "+ str(file))
            
            # get beam energy
            energy = float(str(file).split('_')[-1].replace('.csv.zip', ''))
                
            # load data, get observables
            data = pd.read_csv(str(file))
            observables = calculate_observables(data)
            observables['set'] = dataset
            
            ### obtain number of events (allows for different nevents for different energies)
            nevent = generated_data[int(energy)]
            
            # calculate scaling factor            
            scaling_row = scaling_data[scaling_data['energy'] == round(energy,0)]
            
            cross_section = scaling_row[dataset].values[0]
            flux = scaling_row[dataset[3:]+"_flux"].values[0]  
            weight = ((cross_section * flux * mul)/nevent)   
            observables['weight'] = weight
            
            # combine data
            if all_data is None:all_data = observables
            else:all_data = pd.concat([all_data, observables])
    
    return all_data.reset_index(drop=True)

# %%
data = load_everything(scaling_file='MC_-14_3TeV_with_cut_with_test.txt')
# Out:
# load file: output_events_NC_nuebar/events_112.94.csv.zip
# load file: output_events_NC_nuebar/events_1129.46.csv.zip
# load file: output_events_NC_nuebar/events_14.21.csv.zip
# load file: output_events_NC_nuebar/events_142.19.csv.zip
# load file: output_events_NC_nuebar/events_1421.9.csv.zip
# load file: output_events_NC_nuebar/events_17.9.csv.zip
# load file: output_events_NC_nuebar/events_179.0.csv.zip
# load file: output_events_NC_nuebar/events_22.53.csv.zip
# load file: output_events_NC_nuebar/events_225.35.csv.zip
# load file: output_events_NC_nuebar/events_28.37.csv.zip
# load file: output_events_NC_nuebar/events_283.7.csv.zip
# load file: output_events_NC_nuebar/events_35.71.csv.zip
# load file: output_events_NC_nuebar/events_357.16.csv.zip
# load file: output_events_NC_nuebar/events_44.964.csv.zip
# load file: output_events_NC_nuebar/events_449.64.csv.zip
# load file: output_events_NC_nuebar/events_56.6.csv.zip
# load file: output_events_NC_nuebar/events_566.07.csv.zip
# load file: output_events_NC_nuebar/events_71.26.csv.zip
# load file: output_events_NC_nuebar/events_712.64.csv.zip
# load file: output_events_NC_nuebar/events_89.71.csv.zip
# load file: output_events_NC_nuebar/events_897.16.csv.zip
# load file: output_events_CC_nuebar/events_112.94.csv.zip
# load file: output_events_CC_nuebar/events_1129.46.csv.zip
# load file: output_events_CC_nuebar/events_14.21.csv.zip
# load file: output_events_CC_nuebar/events_142.19.csv.zip
# load file: output_events_CC_nuebar/events_1421.9.csv.zip
# load file: output_events_CC_nuebar/events_17.9.csv.zip
# load file: output_events_CC_nuebar/events_179.0.csv.zip
# load file: output_events_CC_nuebar/events_22.53.csv.zip
# load file: output_events_CC_nuebar/events_225.35.csv.zip
# load file: output_events_CC_nuebar/events_28.37.csv.zip
# load file: output_events_CC_nuebar/events_283.7.csv.zip
# load file: output_events_CC_nuebar/events_35.71.csv.zip
# load file: output_events_CC_nuebar/events_357.16.csv.zip
# load file: output_events_CC_nuebar/events_44.964.csv.zip
# load file: output_events_CC_nuebar/events_449.64.csv.zip
# load file: output_events_CC_nuebar/events_56.6.csv.zip
# load file: output_events_CC_nuebar/events_566.07.csv.zip
# load file: output_events_CC_nuebar/events_71.26.csv.zip
# load file: output_events_CC_nuebar/events_712.64.csv.zip
# load file: output_events_CC_nuebar/events_89.71.csv.zip
# load file: output_events_CC_nuebar/events_897.16.csv.zip
# load file: output_events_CC_numu/events_112.94.csv.zip
# load file: output_events_CC_numu/events_1129.46.csv.zip
# load file: output_events_CC_numu/events_14.21.csv.zip
# load file: output_events_CC_numu/events_142.19.csv.zip
# load file: output_events_CC_numu/events_1421.9.csv.zip
# load file: output_events_CC_numu/events_17.9.csv.zip
# load file: output_events_CC_numu/events_179.0.csv.zip
# load file: output_events_CC_numu/events_22.53.csv.zip
# load file: output_events_CC_numu/events_225.35.csv.zip
# load file: output_events_CC_numu/events_28.37.csv.zip
# load file: output_events_CC_numu/events_283.7.csv.zip
# load file: output_events_CC_numu/events_35.71.csv.zip
# load file: output_events_CC_numu/events_357.16.csv.zip
# load file: output_events_CC_numu/events_44.964.csv.zip
# load file: output_events_CC_numu/events_449.64.csv.zip
# load file: output_events_CC_numu/events_56.6.csv.zip
# load file: output_events_CC_numu/events_566.07.csv.zip
# load file: output_events_CC_numu/events_71.26.csv.zip
# load file: output_events_CC_numu/events_712.64.csv.zip
# load file: output_events_CC_numu/events_89.71.csv.zip
# load file: output_events_CC_numu/events_897.16.csv.zip
# load file: output_events_NC_numu/events_112.94.csv.zip
# load file: output_events_NC_numu/events_1129.46.csv.zip
# load file: output_events_NC_numu/events_14.21.csv.zip
# load file: output_events_NC_numu/events_142.19.csv.zip
# load file: output_events_NC_numu/events_1421.9.csv.zip
# load file: output_events_NC_numu/events_17.9.csv.zip
# load file: output_events_NC_numu/events_179.0.csv.zip
# load file: output_events_NC_numu/events_22.53.csv.zip
# load file: output_events_NC_numu/events_225.35.csv.zip
# load file: output_events_NC_numu/events_28.37.csv.zip
# load file: output_events_NC_numu/events_283.7.csv.zip
# load file: output_events_NC_numu/events_35.71.csv.zip
# load file: output_events_NC_numu/events_357.16.csv.zip
# load file: output_events_NC_numu/events_44.964.csv.zip
# load file: output_events_NC_numu/events_449.64.csv.zip
# load file: output_events_NC_numu/events_56.6.csv.zip
# load file: output_events_NC_numu/events_566.07.csv.zip
# load file: output_events_NC_numu/events_71.26.csv.zip
# load file: output_events_NC_numu/events_712.64.csv.zip
# load file: output_events_NC_numu/events_89.71.csv.zip
# load file: output_events_NC_numu/events_897.16.csv.zip

# %% [markdown]
# - select data with mu+

# %%
data_selected = data[data['e_mu_plus']>10].reset_index(drop=True)

print("All events:", len(data))
print("Events with mu+:", len(data_selected))
# Out:
# All events: 286
# Events with mu+: 154

# %% [markdown]
# - look at some distributions

# %%
sns.histplot(data_selected, x='e_mu_minus')
# Out:
# <AxesSubplot:xlabel='e_mu_minus', ylabel='Count'>

# %%
sns.histplot(data_selected, x='e_mu_plus')
# Out:
# <AxesSubplot:xlabel='e_mu_plus', ylabel='Count'>
