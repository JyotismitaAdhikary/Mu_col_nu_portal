# %% [markdown]
# # Generation of Background Events

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import os
import pythia8

# %% [markdown]
# ## Function that Generates Events for fixed Energy

# %%
def generate_events(energy, nevent=100000, level='hadron', target='W'):
        
    # Setup Pythia
    pythia = pythia8.Pythia()

    # Set random seeds
    pythia.readString("Random:setSeed=on")
    pythia.readString("Random:seed=0")

    # Define beams (frameType = 2 for fixed target collisions)
    pythia.readString("Beams:frameType = 2")
    pythia.readString("Beams:idA = 14")
    pythia.readString("Beams:eA = "+str(energy))
    pythia.readString("Beams:eB = 0")

    # Use the nuclear PDF nCTEQ15 for Tungsten (A=184, Z=74)
    #pdffile = "nCTEQ15FullNuc_56_26_0000.dat"
    #pythia.readString("PDF:pSet=lhagrid1:"+pdffile)
    pdfpath = "/Users/felixkling/work/LHAPDF-6.2.1/installed/share/LHAPDF/nCTEQ15FullNuc_184_74/"
    if target == 'W': pdffile = "nCTEQ15FullNuc_184_74_0000.dat"
    elif target == 'Fe': pdffile = "nCTEQ15FullNuc_56_26_0000.dat"
    pythia.readString("PDF:pSet=LHAGrid1:"+pdfpath+pdffile);

    # Activate necessary options for Pythia
    pythia.readString("PDF:lepton = off")
    pythia.readString("TimeShower:QEDshowerByL = off")

    # Fix Renormalization/Factorization scale
    pythia.readString("SigmaProcess:factorScale2=6")
    pythia.readString("SigmaProcess:renormScale2=6")

    # Minimal phase space cuts
    pythia.readString("PhaseSpace:mHatMin=1")
    pythia.readString("PhaseSpace:pTHatMin=0")
    pythia.readString("PhaseSpace:pTHatMinDiverge=0")

    # Define process (neutrino charge current collision)
    pythia.readString("WeakBosonExchange:ff2ff(t:W)=on")

    # Decide if shower and hadronization should be included
    if level == "hard":
        pythia.readString("HadronLevel:all=off")
        pythia.readString("PartonLevel:all=off")
    elif level == "parton":
        pythia.readString("HadronLevel:all=off")
        pythia.readString("PartonLevel:all=on")
    elif level == "hadron":
        pythia.readString("HadronLevel:all=on")
        pythia.readString("PartonLevel:all=on")
    else:
        print("Error: level = "+level+" is not a valid option")
        return pd.DataFrame()

    # Initialize
    pythia.init()

    # List to store events data for DataFrame
    event_data = []

    # Loop over events
    for ievent in range(nevent):
        
        # Generate next event
        if not pythia.next(): continue
        particles = pythia.process if level == "hard" else pythia.event

        # Loop through particles in event
        iiparticle = 0
        for iparticle, particle in enumerate(particles):
            
            # Reject non-final state particles
            if particle.status() < 0: continue
            # Collect particle data
            pid = particle.id()
            px, py, pz, e = particle.px(), particle.py(), particle.pz(), particle.e()
            parent_pid = particle.mother1()  

            # Append particle data as a new row
            event_data.append([ievent, iiparticle, energy, pid, px, py, pz, e, parent_pid])
            iiparticle+=1

    # Create output directory
    output_dir = "output_events"
    if not os.path.isdir(output_dir): os.makedirs(output_dir)
    #output_dir = pathlib.Path("output_events")
    #output_dir.mkdir(exist_ok=True)
    
    # Convert collected event data to DataFrame
    columns = ["ievent", "iparticle", "truth_energy", "pid", "px", "py", "pz", "e", "parent_pid"]
    df = pd.DataFrame(event_data, columns=columns)
    
    # See if data frame already exist, if yes, merge. 
    csv_file = output_dir+"/events_"+str(energy)+".csv"
    if os.path.exists(csv_file): 
        df_old = pd.read_csv(csv_file)
        nevt_old = df_old['ievent'].max()+1
        df['ievent'] = df['ievent']+ nevt_old
        df = pd.concat([df_old, df]) 
        
    # Export
    df.to_csv(csv_file, index=False)
    print("Saved events for energy "+str(energy)+" to "+csv_file)

# %% [markdown]
# ## Use Function to Generate 100 Events per Energy

# %%
# List of energies
energies = [
    14.219093, 17.900778, 22.535744, 28.370820, 35.716747, 44.964720, 56.607229,
    71.264279, 89.716412, 112.946271, 142.190930, 179.007775, 225.357437,
    283.708205, 357.167468, 449.647202, 566.072289, 712.642790, 897.164117,
    1129.462706, 1421.909302, 1790.077754, 2253.574373, 2837.082046, 3571.674683,
    4496.472021, 5660.722891, 7126.427896, 8971.641174
] 

# Loop through all energies
for energy in energies:
    generate_events(energy=energy, nevent=100, level='hadron')
# Out:
# Saved events for energy 14.219093 to output_events/events_14.219093.csv
# Saved events for energy 17.900778 to output_events/events_17.900778.csv
# Saved events for energy 22.535744 to output_events/events_22.535744.csv
# Saved events for energy 28.37082 to output_events/events_28.37082.csv
# Saved events for energy 35.716747 to output_events/events_35.716747.csv
# Saved events for energy 44.96472 to output_events/events_44.96472.csv
# Saved events for energy 56.607229 to output_events/events_56.607229.csv
# Saved events for energy 71.264279 to output_events/events_71.264279.csv
# Saved events for energy 89.716412 to output_events/events_89.716412.csv
# Saved events for energy 112.946271 to output_events/events_112.946271.csv
# Saved events for energy 142.19093 to output_events/events_142.19093.csv
# Saved events for energy 179.007775 to output_events/events_179.007775.csv
# Saved events for energy 225.357437 to output_events/events_225.357437.csv
# Saved events for energy 283.708205 to output_events/events_283.708205.csv
# Saved events for energy 357.167468 to output_events/events_357.167468.csv
# Saved events for energy 449.647202 to output_events/events_449.647202.csv
# Saved events for energy 566.072289 to output_events/events_566.072289.csv
# Saved events for energy 712.64279 to output_events/events_712.64279.csv
# Saved events for energy 897.164117 to output_events/events_897.164117.csv
# Saved events for energy 1129.462706 to output_events/events_1129.462706.csv
# Saved events for energy 1421.909302 to output_events/events_1421.909302.csv
# Saved events for energy 1790.077754 to output_events/events_1790.077754.csv
# Saved events for energy 2253.574373 to output_events/events_2253.574373.csv
# Saved events for energy 2837.082046 to output_events/events_2837.082046.csv
# Saved events for energy 3571.674683 to output_events/events_3571.674683.csv
# Saved events for energy 4496.472021 to output_events/events_4496.472021.csv
# Saved events for energy 5660.722891 to output_events/events_5660.722891.csv
# Saved events for energy 7126.427896 to output_events/events_7126.427896.csv
# Saved events for energy 8971.641174 to output_events/events_8971.641174.csv

# %% [markdown]
# ## Generate 100 more Events for E=1421.909302

# %%
generate_events(energy=1421.909302, nevent=100, level='hadron')
# Out:
# Saved events for energy 1421.909302 to output_events/events_1421.909302.csv
